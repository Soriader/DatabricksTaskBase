# %%
# %sql

CREATE OR REPLACE TABLE dev.sales.orders_time_travel_drill (
    order_id INT NOT NULL,
    customer_id INT NOT NULL,
    amount INT NOT NULL,
    status STRING NOT NULL
)
USING DELTA;

INSERT INTO dev.sales.orders_time_travel_drill (order_id, customer_id, amount, status) VALUES (1, 1, 100, 'PENDING'), (2, 2, 200, 'COMPLETED'), (3, 3, 300, 'FAILED'), (4, 4, 400, 'DEBITED'), (5, 5, 500, 'COMPLETED');

# %%
# %sql
SELECT *
FROM dev.sales.orders_time_travel_drill;

# %%
# %sql
DESCRIBE HISTORY dev.sales.orders_time_travel_drill;

# %%
# %sql
UPDATE dev.sales.orders_time_travel_drill
SET status = 'FAILED',
    amount = 0;

SELECT *
FROM dev.sales.orders_time_travel_drill;

DESCRIBE HISTORY dev.sales.orders_time_travel_drill;

# %%
# %sql
SELECT *
FROM dev.sales.orders_time_travel_drill VERSION AS OF 1;

# %%
# %sql
RESTORE TABLE dev.sales.orders_time_travel_drill TO VERSION AS OF 1;

# %%
# %sql
SELECT *
FROM dev.sales.orders_time_travel_drill;

# %%
# %sql
DESCRIBE HISTORY dev.sales.orders_time_travel_drill;
